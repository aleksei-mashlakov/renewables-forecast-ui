# %%
# %load_ext autoreload
# %autoreload 2

# %%
import polars as pl

from forecast_ui.utils import JSONUtils

# %%
data = JSONUtils.load_json("./data/solar/forecast.json")
historical_forecasts = pl.DataFrame(data["data"]).select(["datetime", "ci_lower", "forecast", "ci_upper"])

# %%
import plotly.express as px

df = historical_forecasts.with_columns(pl.col("datetime").str.to_datetime()).sort("datetime")
px.line(df, "datetime", y=df.columns[1:])

# %%
df = pl.read_parquet("./data/wind-forecasts.parquet").sort("valid_time").unique("valid_time", keep="last")
px.line(df, "valid_time", y=df.columns[:-1])
